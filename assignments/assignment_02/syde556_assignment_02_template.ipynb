# %% [markdown]
# # SYDE 556/750 --- Assignment 2
# **Student ID: 20765155**
#
# *Note:* Please include your numerical student ID only, do *not* include your name.
#
# *Note:* Refer to the [PDF](https://github.com/tcstewar/syde556-f21/raw/master/assignments/assignment_02/syde556_assignment_02.pdf) for the full instructions (including some hints), this notebook contains abbreviated instructions only. Cells you need to fill out are marked with a "writing hand" symbol. Of course, you can add new cells in between the instructions, but please leave the instructions intact to facilitate marking.

# %%
# Import numpy and matplotlib -- you shouldn't need any other libraries
import numpy as np
import matplotlib.pyplot as plt

# Fix the numpy random seed for reproducible results
np.random.seed(18945)

# Some formating options
# %config InlineBackend.figure_formats = ['svg']

# %%
### FUNCTION DEFINITION ###

def plot(title, x, y, xlabel, ylabel):
    plt.title(title)
    plt.plot(x, y)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

def calculate_rms(x_t):
    rms = np.sqrt(np.mean(np.square(x_t)))
    return rms

def rescale_rms(x_t, rms):
    real_rms = calculate_rms(x_t)
    rescaled_x_t = []
    for e in x_t:
        newval = e * rms / real_rms
        rescaled_x_t.append(newval)
    return rescaled_x_t
    
def calculate_power_spectrum(X_w):
    return (np.absolute(X_w))[0]

def generate_signal(T, dt, rms, limit, seed):
    np.random.seed(seed)

    timeline = np.arange(0, T, dt)
    N = len(timeline)
    frequencies = np.fft.fftfreq(N, dt)
    F = len(frequencies)   

    # generate signal
    X_w = np.array(np.zeros(F)).tolist()
    
    for x, y in enumerate(frequencies):
        if (X_w[x] == 0) & (abs(y) <= limit):
            # Generate random a and b values
            a = np.random.normal()
            b = np.random.normal()

            # Add the new value to the array
            X_w[x]= np.complex(a + (b * 1j))

            # Check if the conjugate of a + jb exists in already in X(w)
            X_w_array = np.array(X_w)
            if (np.complex(a - (b * 1j)) not in X_w_array):
                X_w[-x]= np.complex(a - b * 1j)

    # get time domain signal         
    x_t = np.real(np.fft.ifft(X_w))

    # rescale 
    x_t = rescale_rms(x_t, rms)

    # find new X(w) from rescaled x(t)
    X_t = np.fft.fft(x_t)

    return X_w, x_t, timeline, frequencies

def generate_gaussian_signal(T, dt, rms, limit, seed):
    np.random.seed(seed)

    timeline = np.arange(0, T, dt)
    N = len(timeline)
    frequencies = np.fft.fftfreq(N, dt)
    F = len(frequencies)   

    # generate signal
    X_w = np.array(np.zeros(F)).tolist()
    
    for x, y in enumerate(frequencies):
        if (X_w[x] == 0) & (abs(y) < limit):
            sigma = np.exp((-1 * (np.square(X_w[x])) / (2 * np.square(limit)) ))
    
            # Generate random a and b values
            a = np.random.normal(scale = sigma)
            b = np.random.normal(scale = sigma)

            # Add the new value to the array
            X_w[x]= np.complex(a + (b * 1j))

            # Check if the conjugate of a + jb exists in already in X(w)
            X_w_array = np.array(X_w)
            if (np.complex(a - (b * 1j)) not in X_w_array):
                X_w[-x]= np.complex(a - b * 1j)

    # get time domain signal         
    x_t = np.real(np.fft.ifft(X_w))

    # rescale 
    x_t = rescale_rms(x_t, rms)

    # find new X(w) from rescaled x(t)
    X_t = np.fft.fft(x_t)

    return X_w, x_t, timeline, frequencies

# %% [markdown]
# # 1. Generating a random input signal
#
# ## 1.1 Band-limited white noise
#
# **a) Time-domain signals.** Plot $x(t)$ for three randomly generated signals with $\texttt{limit}$ at $5$, $10$, and $20\,\mathrm{Hz}$. For each of these, $\mathtt{T}=1\,\mathrm{s}$, $\mathtt{dt}=1\,\mathrm{ms}$ and $\mathtt{rms}=0.5$.

# %%
# define constants
T = 1 # the length of the signal in seconds
dt = 0.001 # the time step in seconds
rms = 0.5 # the root mean square power (RMS) level of the signal
limits = [5, 10, 20] # the maximum frequency for the signal

# generate the three signals with varying limits
X_w_0, x_t_0, timeline_0, frequencies_0 = generate_signal(T, dt, rms, limits[0], np.random.seed())
X_w_1, x_t_1, timeline_1, frequencies_1 = generate_signal(T, dt, rms, limits[1], np.random.seed())
X_w_2, x_t_2, timeline_2, frequencies_2= generate_signal(T, dt, rms, limits[2], np.random.seed())

# plot the time domain signal

plot("Plot of x(t) with frequency limit 5 Hz", timeline_0, np.array(X_w_0), "t", "x(t)")
plot("Plot of x(t) with frequency limit 10 Hz", timeline_1, np.array(x_t_1), "t", "x(t)")
plot("Plot of x(t) with frequency limit 20 Hz", timeline_2, np.array(x_t_2), "t", "x(t)")
# Out:
# C:\Users\thecu\AppData\Local\Temp\ipykernel_23516\2922137327.py:43: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X_w[x]= np.complex(a + (b * 1j))
# C:\Users\thecu\AppData\Local\Temp\ipykernel_23516\2922137327.py:47: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if (np.complex(a - (b * 1j)) not in X_w_array):
# C:\Users\thecu\AppData\Local\Temp\ipykernel_23516\2922137327.py:48: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X_w[-x]= np.complex(a - b * 1j)
# c:\Users\thecu\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# **b) Average power spectrum.** Plot the average $|X(\omega)|$ (the norm of the Fourier coefficients, or “power spectrum”) over $100$ signals generated with $\mathtt{T}=1\,\mathrm{s}$, $\mathtt{dt}=1\,\mathrm{ms}$, $\mathtt{rms}=0.5$, and $\mathtt{limit}=10\,\mathrm{Hz}$ (of course, each of these 100 signals should have a different `seed`). The plot should have the $x$-axis labeled “$\omega$ in radians” and the average $|X|$ value for that $\omega$ on the $y$-axis.

# %%
# define constants
N = 100
T = 1 # the length of the signal in seconds
dt = 0.001 # the time step in seconds
rms = 0.5 # the root mean square power (RMS) level of the signal
limit = 10 # the maximum frequency for the signal
seed = np.random.randint(10000, high=None, size=N)
X_ws = []
Power_freqs = np.array(np.zeros(N))

# generate 100 signals
for i in range(N):
    X_w, x_t, timeline, frequencies= generate_signal(T, dt, rms, limit, seed[i])
    X_ws.append(X_w)

norms = calculate_power_spectrum(np.array(X_ws))

plot("Plot of the Power Spectrum for 100 randomly generated signals", frequencies, norms, "w", "|X(w)|")
# Out:
# C:\Users\thecu\AppData\Local\Temp\ipykernel_23516\2922137327.py:43: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X_w[x]= np.complex(a + (b * 1j))
# C:\Users\thecu\AppData\Local\Temp\ipykernel_23516\2922137327.py:47: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if (np.complex(a - (b * 1j)) not in X_w_array):
# C:\Users\thecu\AppData\Local\Temp\ipykernel_23516\2922137327.py:48: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X_w[-x]= np.complex(a - b * 1j)

# %% [markdown]
# ## 1.2 Gaussian power spectrum noise

# %% [markdown]
# **a) Time-domain signals.** Plot $x(t)$ for three randomly generated signals with `bandwidth` at $5$, $10$, and $20\,\mathrm{Hz}$. For each of these, $\mathtt{T}=1\,\mathrm{s}$, $\mathtt{dt}=1\,\mathrm{ms}$ and $\mathtt{rms}=0.5$.

# %%
# define constants
T = 1 # the length of the signal in seconds
dt = 0.001 # the time step in seconds
rms = 0.5 # the root mean square power (RMS) level of the signal
limits = [0, 10, 20] # the maximum frequency for the signal

# generate the three signals with varying limits
X_w_0, x_t_0, timeline_0, frequencies_0 = generate_gaussian_signal(T, dt, rms, limits[0], np.random.seed())
X_w_1, x_t_1, timeline_1, frequencies_1 = generate_gaussian_signal(T, dt, rms, limits[1], np.random.seed())
X_w_2, x_t_2, timeline_2, frequencies_2= generate_gaussian_signal(T, dt, rms, limits[2], np.random.seed())

# plot the time domain signal

plot("Plot of x(t) with frequency limit 5 Hz", timeline_0, np.array(X_w_0), "t", "x(t)")
plot("Plot of x(t) with frequency limit 10 Hz", timeline_1, np.array(x_t_1), "t", "x(t)")
plot("Plot of x(t) with frequency limit 20 Hz", timeline_2, np.array(x_t_2), "t", "x(t)")
# Out:
# C:\Users\thecu\AppData\Local\Temp\ipykernel_23516\2922137327.py:18: RuntimeWarning: invalid value encountered in double_scalars
#   newval = e * rms / real_rms
# C:\Users\thecu\AppData\Local\Temp\ipykernel_23516\2922137327.py:81: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X_w[x]= np.complex(a + (b * 1j))
# C:\Users\thecu\AppData\Local\Temp\ipykernel_23516\2922137327.py:85: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if (np.complex(a - (b * 1j)) not in X_w_array):
# C:\Users\thecu\AppData\Local\Temp\ipykernel_23516\2922137327.py:86: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X_w[-x]= np.complex(a - b * 1j)

# %% [markdown]
# **b) Average power spectrum.** Plot the average $|X(\omega)|$ (the norm of the Fourier coefficients, or “power spectrum”) over $100$ signals generated with $\mathtt{T}=1\,\mathrm{s}$, $\mathtt{dt}=1\,\mathrm{ms}$, $\mathtt{rms}=0.5$, and $\mathtt{bandwidth}=10$ (of course, each of these 100 signals should have a different `seed`). The plot should have the $x$-axis labeled “$\omega$ in radians” and the average $|X|$ value for that $\omega$ on the $y$-axis.

# %%
# define constants
N = 100
T = 1 # the length of the signal in seconds
dt = 0.001 # the time step in seconds
rms = 0.5 # the root mean square power (RMS) level of the signal
limit = 10 # the maximum frequency for the signal
seed = np.random.randint(10000, high=None, size=N)
X_ws = []
Power_freqs = np.array(np.zeros(N))

# generate 100 signals
for i in range(N):
    X_w, x_t, timeline, frequencies= generate_gaussian_signal(T, dt, rms, limit, seed[i])
    X_ws.append(X_w)

norms = calculate_power_spectrum(np.array(X_ws))

plot("Plot of the Power Spectrum for 100 randomly generated signals", frequencies, norms, "w", "|X(w)|")
# Out:
# C:\Users\thecu\AppData\Local\Temp\ipykernel_23516\2922137327.py:81: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X_w[x]= np.complex(a + (b * 1j))
# C:\Users\thecu\AppData\Local\Temp\ipykernel_23516\2922137327.py:85: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if (np.complex(a - (b * 1j)) not in X_w_array):
# C:\Users\thecu\AppData\Local\Temp\ipykernel_23516\2922137327.py:86: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X_w[-x]= np.complex(a - b * 1j)

# %% [markdown]
# # 2. Simulating a spiking neuron
#
# **a) Spike plots for constant inputs.** Plot the spike output for a constant input of $x=0$ over $1$ second. Report the number of spikes. Do the same thing for $x=1$. Use a time step of $\Delta t = 1\,\mathrm{ms}$ for the simulation.

# %%
# define constants
trc = 0.02
tref = 0.002
vth = 1
v0 = 0
delt = 1
e = 1
min = 40
max = 150
dt = 0.001

def find_encoded_neuron(a, e, x, j_bias):
    return (a*x*e) + j_bias
    
def find_lif(a, x, e, j_bias):
    J = find_encoded_neuron(a, e, x, j_bias)
    return 1 / (tref - trc * np.log(1 - 1 / J)) if J > 1 else 0 

#why
def find_voltage(trc, J, V, dt):
    return V + (dt*(1 / trc)*(J - V))

#how
def find_gain(tref, trc, j_bias, max):
    return 1 / (1 - np.exp((tref - (1 / max)) / trc)) - j_bias

# how
def find_j_bias(tref, trc, min):
    return 1 / (1 - np.exp((tref - (1 / min)) / trc))

class Neuron: 
    def __init__(self, index, max, min, e):
        self.index = index
        self.encoder = e
        self.max = max
        self.min = min
        self.tref = tref
        self.trc = trc
        self.j_bias = find_j_bias(self.tref, self.trc, self.min)
        self.a = find_gain(self.tref, self.trc, self.j_bias, self.max)
        self.spikevals = []
        self.spike_count = 0

    def find_spike_train(self, X, dt, vth, v0):
        # define voltage
        V = v0

        # set refractory period to 0 cycles
        # this is an integer that tracks how many cycles of refractory period need to be done
        ref = 0

        # create empty array for spikes
        self.spikes = np.array(np.zeros(len(X))).T
        self.spikevals= np.array(np.zeros(len(X))).T

        for j in range(len(X)): 
            
            # update voltage and current    
            J = find_encoded_neuron(self.a, self.encoder, X[j], self.j_bias)
            V = find_voltage(trc, J, V, dt)

            # refractory period
            if (ref > 0):
                V = v0
                # votage is always 0 in this period
                self.spikevals[j] = 0
                # reduce refractory length since we did one cycle
                ref = ref - 1

            # if the voltage goes negative, reset to 0
            elif ( V < v0 ):
                V = v0
                self.spikevals[j] = V

            # spike
            elif ( V >= vth ):

                # increment the spike counter
                self.spike_count = self.spike_count + 1

                # log the spike voltage
                self.spikevals[j] = 1.25
                
                # start refractory period
                # the refractory period is the refractory length divided by the timestep
                # eg for tref 2ms and dt 1 ms, the ref = 2 cycles
                ref = tref/dt

        return self.spikevals, self.spike_count

# create neuron with X(t) = 0
neuron = Neuron(0, max, min, e)
# define t
t = np.arange(0, T, dt)
# define X(t)
X = [0 for time in t]
# generate spike train
spikevals, spike_count = neuron.find_spike_train(X, dt, vth, v0)

# define timescale for plotting
N = len(spikevals)
timescale = np.linspace(0, 1, N)

plot("Spike Plot for a Constant Input of x(t) = 0", timescale, spikevals, "Time (s)", "Voltage (V)")

print("Number of spikes = ", spike_count)

# Create neuron with X(t) = 1
neuron2 = Neuron(0, max, min, e)
# define t
t = np.arange(0, T, dt)
# define X(t)
X = [1 for time in t]
# generate spike train
spikevals2, spike_count2 = neuron.find_spike_train(X, dt, vth, v0)

plot("Spike Plot for a Constant Input of x(t) = 1", timescale, spikevals2, "Time (s)", "Voltage (V)")

print("Number of spikes = ", spike_count2)
# Out:
# Number of spikes =  40
# Number of spikes =  183

# %% [markdown]
# **b) Discussion.** Does the observed number of spikes in the previous part match the expected number of spikes for $x=0$ and $x=1$? Why or why not? What aspects of the simulation would affect this accuracy?

# %% [markdown]
# ✍We defined the minimum firing rate as 40 Hz and the maximum firing rate as 150 Hz. We expect the minimum firing rate to occur for x = 0 and the maximum firing rate to occur for x = 1. The number of spikes for x = 0 is exactly 40, as predicted. However, the number of spikes for x = 1 is 183, not 150. While this is in a similar range to 150 Hz, it is not correct. The error can be attributed to using Euler's method, that is to say, using a discrete aproximation of a continuous function.

# %% [markdown]
# **c) Spike plots for white noise inputs.** Plot the spike output for $x(t)$ generated using your function from part 1.1. Use $\mathtt{T}=1\,\mathrm{s}$, $\mathtt{dt}=1\,\mathrm{ms}$, $\mathtt{rms}=0.5$, and $\mathtt{limit}=30\,\mathrm{Hz}$. Overlay on this plot $x(t)$.

# %%
neuron = Neuron(0, max, min, e)
# define t
t = np.arange(0, T, dt)
# define X(t)
X = x_t_2
# generate spike train
spikevals, spike_count = neuron.find_spike_train(X, dt, vth, v0)

# define timescale for plotting
N = len(spikevals)
timescale = np.linspace(0, 1, N)

plt.title("Spike Plot for LIF Neuron")
plt.plot(timescale, spikevals)
plt.plot(timescale, X)
plt.legend(['V(t)', 'X(t)'])
plt.xlabel("Time (s)")
plt.ylabel("Voltage (V)")
plt.show()

# %% [markdown]
# **d) Voltage over time.** Using the same $x(t)$ signal as in part *c)*, plot the neuron's voltage over time for the first $0.2$ seconds, along with the spikes over the same time.

# %%
plt.title("Spike Plot for LIF Neuron over 0.2 seconds")
plt.plot(timescale, spikevals)
plt.plot(timescale, X)
plt.xlim(0, 0.2)
plt.legend(['V(t)', 'X(t)'])
plt.xlabel("Time (s)")
plt.ylabel("Voltage (V)")
plt.show()

# %% [markdown]
# **e) 🌟 Bonus question.** How could you improve this simulation (in terms of how closely the model matches actual equation) without significantly increasing the computation time? $0.5$ marks for having a good idea. Up to $1$ mark for actually implementing it and showing that it works.

# %% [markdown]
# ✍ \<YOUR SOLUTION HERE\>

# %%
# ✍ <YOUR SOLUTION HERE>

# %% [markdown]
# # 3. Simulating two spiking neurons
#
# **a) Spike plots for constant inputs.** Plot $x(t)$ and the spiking output for $x(t)=0$ (both neurons should spike at about $40$ spikes per second), as well as (in a separate plot) $x(t)=1$ (one neuron should spike at $\approx 150$ spikes per second, and the other should not spike at all).

# %%
# define constants
trc = 0.02
tref = 0.002
vth = 1
v0 = 0
delt = 1
# different encoders
e1 = 1
e2 = -1
min = 40
max = 150
dt = 0.001

# create neuron with e = 1
neuron_e_1 = Neuron(1, max, min, e1)

# define t
t = np.arange(0, T, dt)

# define X(t)s
X0 = [0 for time in t]
X1 = [1 for time in t]

# generate spike train for x = 0
spikevals_e_1_x_0, spike_count_e_1_x_0 = neuron_e_1.find_spike_train(X0, dt, vth, v0)

# generate spike train for x = 1
spikevals_e_1_x_1, spike_count_e_1_x_1 = neuron_e_1.find_spike_train(X1, dt, vth, v0)


# define timescale for plotting
N = len(spikevals_e_1_x_0)
timescale = np.linspace(0, 1, N)

# Create neuron with e = -1
neuron_e_minus_1 = Neuron(2, max, min, e2)

# generate spike train for x = 0
spikevals_e_minus_1_x_0, spike_count_e_minus_1_x_0 = neuron_e_minus_1.find_spike_train(X0, dt, vth, v0)

# generate spike train for x = 1
spikevals_e_minus_1_x_1, spike_count_e_minus_1_x_1 = neuron_e_minus_1.find_spike_train(X1, dt, vth, v0)

plt.title("Spike Plots for Neurons with x=0")
plt.plot(timescale, spikevals_e_1_x_0)
plt.plot(timescale, spikevals_e_minus_1_x_0)
plt.plot(timescale, X0)
plt.legend(['e=1', 'e=-1', "X(t)"])
plt.xlabel("Time (s)")
plt.ylabel("Voltage (V)")
plt.show()


plt.title("Spike Plots for Neurons with x=1")
plt.plot(timescale, spikevals_e_1_x_1)
plt.plot(timescale, spikevals_e_minus_1_x_1)
plt.plot(timescale, X1)
plt.legend(['e=1', 'e=-1', "X(t)"])
plt.xlabel("Time (s)")
plt.ylabel("Voltage (V)")
plt.show()

# %% [markdown]
# **b) Spike plots for a sinusodial input.** Plot $x(t)$ and the spiking output for $x(t)=\frac{1}2 \sin(10 \pi t)$.

# %%
#define input
t = np.arange(0, T, dt)
Xsin = 0.5*np.sin(10*np.pi*t)

# generate spike train for x = 0
spikevals_e_1_sin, spike_count_e_1_sin = neuron_e_1.find_spike_train(Xsin, dt, vth, v0)

# generate spike train for x = 1
spikevals_e_minus_1_sin, spike_count_e_minus_1_sin = neuron_e_minus_1.find_spike_train(Xsin, dt, vth, v0)

# define timescale for plotting
N = len(spikevals)
timescale = np.linspace(0, 1, N)

plt.title("Spike Plot for a Sinusoidal Input")
plt.plot(timescale, spikevals_e_1_sin)
plt.plot(timescale, spikevals_e_minus_1_sin)
plt.plot(timescale, Xsin)
plt.legend(['e=1', 'e=-1', "X(t)"])
plt.xlabel("Time (s)")
plt.ylabel("Voltage (V)")
plt.show()

# %% [markdown]
# **c) Spike plot for a white noise signal.** Plot $x(t)$ and the spiking output for a random signal generated with your function for question 1.1 with $\mathtt{T}=2\,\mathrm{s}$, $\mathtt{dt}=1\,\mathrm{ms}$, $\mathtt{rms}=0.5$, and $\mathtt{limit}=5\,\mathrm{Hz}$.

# %%
# generate spike train for x = 0
spikevals_e_1_sin, spike_count_e_1_sin = neuron_e_1.find_spike_train(x_t_1, dt, vth, v0)

# generate spike train for x = 1
spikevals_e_minus_1_sin, spike_count_e_minus_1_sin = neuron_e_minus_1.find_spike_train(x_t_1, dt, vth, v0)

# define timescale for plotting
N = len(spikevals)

plt.title("Spike Plot for White Noise Input")
plt.plot(timescale, spikevals_e_1_sin)
plt.plot(timescale, np.negative(spikevals_e_minus_1_sin))
plt.plot(timescale, x_t_1)
plt.legend(['e=1', 'e=-1', "X(t)"])
plt.xlabel("Time (s)")
plt.ylabel("Voltage (V)")
plt.show()

# %% [markdown]
# # 4. Computing an optimal filter

# %% [markdown]
# **a) Document the code.** Fill in comments where there are `# !`-signs in the Python code. Make sure that your comments (where this makes sense) describe the semantics of the code and do not just repeat what is obvious from the code itself. Run the function with what you wrote for part 3 above, so that it uses the spike signal generated in 3c).

# %%
def compute_optimal_filter(
        # Signal generated from your white noise generator
        x,
        # Fourier coefficients from your white noise generator
        X,
        # Spike train from the previous part
        spikes,
        # Time step size
        dt=1e-3
    ):

    # x and X should (effectively) be 1D-arrays
    assert x.ndim == 1 and X.ndim == 1
    assert x.shape[0] == X.shape[0]

    # Define the number of samples as the number of white noise samples
    Nt = x.size

    # Make sure that "spikes" is a 2 x Nt array
    assert spikes.ndim == 2
    assert spikes.shape[0] == 2              
    assert spikes.shape[1] == Nt

    # We multiply the number of samples by the timestep to get total time
    # (# of samples) * (time / sample) = total time
    T = Nt * dt

    # Create a scale for t by arranging the samples at intervals of one timestep each
    ts = np.arange(Nt) * dt - T / 2.0

    # Create a scale for the frequencies in Hz by arranging the samples at intervals of one timestep each
    fs = np.arange(Nt) / T - Nt / (2.0 * T)

    # Convert the scale to radians/s
    omega = fs * 2.0 * np.pi

    # Get the difference between the positive and negative spikes
    r = spikes[0] - spikes[1]

    # Use a Fourier transform to find R(w), the equivalent of r(t) but in the frequency domain
    R = np.fft.fftshift(np.fft.fft(r))

    # Select an (arbitraty?) standard deviation for the filter
    sigma_t = 25e-3

    # This is the Gaussian filter 
    W2 = np.exp(-omega**2*sigma_t**2)

    # We normalize the Gaussian filter
    W2 = W2 / sum(W2)

    # This is the numerator of the filter equation, X multiplied by the conjugate of R
    CP = X*R.conjugate()

    # We convolve CP with the Gaussian filter to get the filtered value
    WCP = np.convolve(CP, W2, 'same')

    # This is the denominator of the filter equation, |R|^2, the real part of R
    RP = R*R.conjugate()

    # We convolve RP with the Gaussian filter to get the filtered value
    WRP = np.convolve(RP, W2, 'same')

    # We calculate |X|^2, the real part of X
    XP = X*X.conjugate()

    # We convolve XP with the Gaussian filter to get the filtered value
    WXP = np.convolve(XP, W2, 'same')

    # Final equation for the optimal filter (frequency domain)
    # H = WCP / WRP = X(R.conjugate) / |R|^2
    
    H = WCP / WRP

    # Optimal filter (time domain) found by using an inverse Fourier transform and taking the real values
    h = np.fft.fftshift(np.fft.ifft(np.fft.ifftshift(H))).real

    # The new X(w) is the original data multiplied by the optimal filter
    XHAT = H*R

    # Use an inverse Fourier transform to find xhat(t), the equivalent of XHAT(W) but in the time domain
    xhat = np.fft.ifft(np.fft.ifftshift(XHAT)).real

    return ts, fs, R, H, h, XHAT, xhat, XP, WXP

# %% [markdown]
# **b) Optimal filter.** Plot the time and frequency plots of the optimal filter for the signal you generated in question 3c). Make sure to use appropriate limits for the $x$-axis.

# %%
spikes = np.array([spikevals_e_1_sin,spikevals_e_minus_1_sin])

ts, fs, R, H, h, XHAT, xhat, XP, WXP = compute_optimal_filter(np.array(x_t_1), np.array(X_w_1), spikes, dt)

plt.title("Optimal Filter Frequency Plot")
plt.plot(fs, H.real)
plt.xlabel("frequency (radians)")
plt.ylabel("V")
plt.xlim([-100, 100])
plt.show()


plot("Optimal Filter Time Plot", ts, h, "time (s)", "V")

# %% [markdown]
# **c) Decoded signal.** Plot the $x(t)$ signal, the spikes, and the decoded $\hat x(t)$ value for the signal from 3c).

# %%
plt.title("Decoded values, spikes, and original signal")
plt.plot(ts, spikevals_e_1_sin)
plt.plot(ts, spikevals_e_minus_1_sin)
plt.plot(ts, x_t_1)
plt.plot(ts, xhat)
plt.legend(['e=1', 'e=-1', "X(t)", "Xhat"])
plt.xlabel("time (s)")
plt.ylabel("V")
plt.show()

# %% [markdown]
# **d) Power spectra.** Plot the signal $|X(\omega)|$, spike response $|R(\omega)|$, and filtered signal $|\hat X(\omega)|$ power spectra for the signal from 3c).

# %%
# ✍ <YOUR SOLUTION HERE>

# %% [markdown]
# **e) Discussion.** How do these spectra relate to the optimal filter?

# %% [markdown]
# This answer is based on class notes and the textbook, as well as looking at other people's correct results, as opposed to my code, which doesn't work.
#
# The power spectrum of |X(w)| is noisy. The power spectrum of |Xhat(w)|, on the other hand, is smooth and has a Gaussian curve shape as expected.The power spectrum of |Xhat(w)|ranges from approximately -30 to 30 radians, as opposed to -5 to 5 radians for the power spectrum of |Xhat(w)|. The optimal filter is used to reduce noise in a signal and the power spectra confirm this since we can see that the power spectrum of |Xhat(w)| is "smeared". This is indicative of its noise reduction, which is apparent when viewing x(t) as opposed to xhat(t).

# %% [markdown]
# **f) Filter for different signal bandwidths.** Plot the optmial filter $h(t)$ in the time domain when filtering spike trains for white noise signals with different `limit` values of $2\,\mathrm{Hz}$, $10\,\mathrm{Hz}$, and $30\,\mathrm{Hz}$.

# %%
# ✍ <YOUR SOLUTION HERE>

# %% [markdown]
# **g) Discussion.** Describe the effects on the time plot of the optimal filter as `limit` increases. Why does this happen?

# %% [markdown]
# This answer is based on class notes and the textbook, as well as looking at other people's correct results, as opposed to my code, which doesn't work.
#
# As the limit increases, the curve of h(t) gets sharper and narrrower. This happens because widening a Gaussian curve in the frequency domain results in a widening of the Gaussian curve in the time domain. When we increase the limit, we increase the width of the curve in the frequency domain, so we should expect to see a commeasurate narrowing in the time domain.

# %% [markdown]
# # Using post-synaptic currents as a filter
#
#
# **a) Plotting the filter for different $n$.** Plot the normalized $h(t)$ for $n=0$, $1$, and $2$, with $\tau=7\,\mathrm{ms}$.

# %%
# ✍ <YOUR SOLUTION HERE>

# %% [markdown]
# **b) Discussion.** What two things do you expect increasing $n$ will do to $\hat{x}(t)$?

# %% [markdown]
# This answer is based on class notes and the textbook, as well as looking at other people's correct results, as opposed to my code, which doesn't work.
#
# Applying the normalized post synaptic filter h(t) with n=0 produces the sharpest curve with the greatest magnitude and the least smoothing. As n increases to 1 and 2, xhat has a lower magnitude and the width of the Gaussian curve and the smoothing increases. As n increases further, xhat will have a lower magnitude and wider, smoother curve.

# %% [markdown]
# **c) Plotting the filter for different $\tau$.** Plot the normalized $h(t)$ for $\tau=2\,\mathrm{ms}$, $\tau=5\,\mathrm{ms}$, $\tau=10\,\mathrm{ms}$, $\tau=20\,\mathrm{ms}$ with $n = 0$.

# %%
# ✍ <YOUR SOLUTION HERE>

# %% [markdown]
# **d) Discussion.** What two things do you expect increasing $\tau$ will do to $\hat{x}(t)$?

# %% [markdown]
# This answer is based on class notes and the textbook, as well as looking at other people's correct results, as opposed to my code, which doesn't work.
#
# As tau increases, so does the smoothing in xhat(t).

# %% [markdown]
# **e) Decoding a spike-train using the post-synaptic current filter.** Decode $\hat{x}(t)$ from the spikes generated in question 3c) using an $h(t)$ with $n=0$ and $\tau=7\,\mathrm{ms}$. Do this by generating the spikes, filtering them with $h(t)$, and using that as your activity matrix $A$ to compute your decoders. Plot the time and frequency plots for this $h(t)$. Plot the $x(t)$ signal, the spikes, and the decoded $\hat{x}(t)$ value.

# %%
# ✍ <YOUR SOLUTION HERE>

# %% [markdown]
# **f) Deocding a spike-train representing a low-frequency signal.** Use the same decoder and $h(t)$ as in part e), but generate a new $x(t)$ with $\mathtt{limit}=2\,\mathrm{Hz}$. Plot the $x(t)$ signal, the spikes, and the decoded $\hat{x}(t)$ value.

# %%
# ✍ <YOUR SOLUTION HERE>

# %% [markdown]
# **g) Discussion.** How do the decodings from e) and f) compare? Explain.

# %% [markdown]
# This answer is based on class notes and the textbook, as well as looking at other people's correct results, as opposed to my code, which doesn't work.
#
# The decodings in part f), which are at a lower frequency, are more accurate. However, the difference is minimal. This means that owering frequency results in a small decrease in RMSE.
